# %% [markdown]
# ## Download Bird Song Dataset ##
# Code copied from https://www.kaggle.com/datasets/rtatman/british-birdsong-dataset/data

# %%
# !pip install kagglehub
# Out:
# ...
#
#    ---- -----------------------------------  1/10 [tqdm]
#    -------- -------------------------------  2/10 [pyyaml]
#    ------------ ---------------------------  3/10 [protobuf]
#    ------------ ---------------------------  3/10 [protobuf]
#    ---------------- -----------------------  4/10 [idna]
#    ---------------------------- -----------  7/10 [requests]
#    -------------------------------- -------  8/10 [kagglesdk]
#    -------------------------------- -------  8/10 [kagglesdk]
#    -------------------------------- -------  8/10 [kagglesdk]
#    -------------------------------- -------  8/10 [kagglesdk]
#    -------------------------------- -------  8/10 [kagglesdk]
#    -------------------------------- -------  8/10 [kagglesdk]
#    ------------------------------------ ---  9/10 [kagglehub]
#    ---------------------------------------- 10/10 [kagglehub]
#
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rtatman/british-birdsong-dataset")

print("Path to dataset files:", path)
# Out:
# Resuming download from 39845888 bytes (624417291 bytes left)...
# Resuming download to C:\Users\Barka\.cache\kagglehub\datasets\rtatman\british-birdsong-dataset\2.archive (39845888/664263179) bytes left.
# 100%|██████████| 633M/633M [02:06<00:00, 4.94MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Barka\.cache\kagglehub\datasets\rtatman\british-birdsong-dataset\versions\2
